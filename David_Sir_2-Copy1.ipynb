# %%
import numpy as np
import pandas as pd

# %%
DivyaMam = pd.read_csv('Email Ids - DivyaMam.csv')
GR = pd.read_csv('Email Ids -  G R.csv')
Ashini = pd.read_csv('Email Ids - Ashini.csv')
Bihar = pd.read_csv('Email Ids - Bihar & Jharkhand.csv')
Yogen = pd.read_csv('Email Ids - Mr Yogen.csv', skiprows=1)
Priyanka = pd.read_csv('Email Ids - Ms. Priyanka.csv')
Odisha = pd.read_csv('Email Ids - odisha.csv', skiprows=1)
Others = pd.read_csv('Email Ids - Others.csv')
Raksha = pd.read_csv('Email Ids - Raksha.csv')
Sheet12 = pd.read_csv('Email Ids - Sheet12.csv')
dam = pd.read_csv('Email Ids - tfdam_raksha.csv')
WB = pd.read_csv('Email Ids - WB & North East.csv', skiprows=1)

# %%
DivyaMam
# Out:
#                            Name                            email  \
# 0               Adrijit Goswami       goswami@maths.iitkgp.ac.in
# 1                 Asish Ganguly      aganguly@maths.iitkgp.ac.in
# 2           Umesh Chandra Gupta         umesh@maths.iitkgp.ac.in
# 3            Bappaditya Bhowmik    bappaditya@maths.iitkgp.ac.in
# 4               Bibhas Adhikari        bibhas@maths.iitkgp.ac.in
# 5                 Chandal Nahak        cnahak@maths.iitkgp.ac.in
# 6              Debapriya Biswas         priya@maths.iitkgp.ac.in
# 7           Debjani Chakraborty       debjani@maths.iitkgp.ac.in
# 8              Geetanjali Panda    geetanjali@maths.iitkgp.ac.in
# 9          Gnaneshwar Nelakanti       gnanesh@maths.iitkgp.ac.in
# 10              G P Raja Sekhar               rajas@iitkgp.ac.in
# 11          Hari Shankar Mahato      hsmahato@maths.iitkgp.ac.in
# 12               Jitendra Kumar        jkumar@maths.iitkgp.ac.in
# ...

# %%
GR
# Out:
#      Sl. No.                             NAME  \
# 0          1           Dr. Th. Somchand Singh
# 1          2             Sangeeta Shougrakpam
# 2          3        Mr. Nahakpam Hitler Singh
# 3          4               Dr.P. Albino Kumar
# 4          5       Dr. Thiyam Tamphasana Devi
# 5          6          Ms. Sarungbam Pipileima
# 6          7            Mr. Nzanthung Ngullie
# 7          8          Prof. Dr. Asis Mazumdar
# 8          9           Dr. (Mrs.) Debasri Roy
# 9         10      Prof. DR. Ashok Kumar Gupta
# 10        11                 Bhabagrahi Sahoo
# 11        12                Kalyan Kumar Bhar
# 12        13                 Pranab Kumar Lai
# 13        14                 Sandipan Ganguly
# 14        15                    Prithwish Roy
# 15        16            Dr Mrinal Kumar Dutta
# 16        17                Dr Pankaj Goswami
# 17        18             Dr Bharati Medhi Das
# 18        19              Dr Triptimani Borah
# ...

# %%
Ashini
# Out:
#        nairdarshan_balan@yahoo.co.in
# 0           hod.cse@audisankara.com.
# 1           hod.cse@audisankara.com.
# 2                    jc@nerist.ac.in
# 3                 hodma@nerist.ac.in
# 4                   jc@nerist.ac.in.
# 5     principal@midnaporecollege.org
# 6         info@burdwanrajcollege.net
# 7                   rajesh@bcrec.org
# 9                 Ms. Shailaja.S.R               shailaja@drttit.edu.in
# 10                             NaN       principalslnenggcr@hkes.edu.in
# 11                             NaN         principal_sln@rediffmail.com
# ...

# %%
sheets = [DivyaMam,GR,Ashini,Bihar,Yogen,Priyanka,Odisha,Others,Raksha,WB, Sheet12, dam]

# %%
sheets
# Out:
# [                           Name                            email  \
#  0               Adrijit Goswami       goswami@maths.iitkgp.ac.in
#  1                 Asish Ganguly      aganguly@maths.iitkgp.ac.in
#  2           Umesh Chandra Gupta         umesh@maths.iitkgp.ac.in
#  3            Bappaditya Bhowmik    bappaditya@maths.iitkgp.ac.in
#  4               Bibhas Adhikari        bibhas@maths.iitkgp.ac.in
#  5                 Chandal Nahak        cnahak@maths.iitkgp.ac.in
#  6              Debapriya Biswas         priya@maths.iitkgp.ac.in
#  7           Debjani Chakraborty       debjani@maths.iitkgp.ac.in
#  8              Geetanjali Panda    geetanjali@maths.iitkgp.ac.in
#  9          Gnaneshwar Nelakanti       gnanesh@maths.iitkgp.ac.in
#  10              G P Raja Sekhar               rajas@iitkgp.ac.in
#  11          Hari Shankar Mahato      hsmahato@maths.iitkgp.ac.in
#  12               Jitendra Kumar        jkumar@maths.iitkgp.ac.in
# ...

# %%
df = [{'k1':DivyaMam, 'k2':GR, 'k3':Ashini, 'k4':Bihar,'k5':Yogen, 'k6':Priyanka, 'k7':Odisha, 'k8':Others,'k9': Raksha,'k10':WB, 'k11':Sheet12, 'K12':dam}]

# %%
df
# Out:
# [{'k1':                            Name                            email  \
#   0               Adrijit Goswami       goswami@maths.iitkgp.ac.in
#   1                 Asish Ganguly      aganguly@maths.iitkgp.ac.in
#   2           Umesh Chandra Gupta         umesh@maths.iitkgp.ac.in
#   3            Bappaditya Bhowmik    bappaditya@maths.iitkgp.ac.in
#   4               Bibhas Adhikari        bibhas@maths.iitkgp.ac.in
#   5                 Chandal Nahak        cnahak@maths.iitkgp.ac.in
#   6              Debapriya Biswas         priya@maths.iitkgp.ac.in
#   7           Debjani Chakraborty       debjani@maths.iitkgp.ac.in
#   8              Geetanjali Panda    geetanjali@maths.iitkgp.ac.in
#   9          Gnaneshwar Nelakanti       gnanesh@maths.iitkgp.ac.in
#   10              G P Raja Sekhar               rajas@iitkgp.ac.in
#   11          Hari Shankar Mahato      hsmahato@maths.iitkgp.ac.in
#   12               Jitendra Kumar        jkumar@maths.iitkgp.ac.in
# ...

# %%
import csv

with open('Email.csv', 'w', encoding="utf-8") as csvFile:
    fields = ['k1','k2','k3','k4','k5','k6','k7','k8','k9','k10','k11','k12']
    writer = csv.DictWriter(csvFile, fieldnames = fields)
    writer.writeheader()
    writer.writerows(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-bfedefd215b6> in <module>
#       5     writer = csv.DictWriter(csvFile, fieldnames = fields)
#       6     writer.writeheader()
# ----> 7     writer.writerows(df)
#
# ~\Anaconda3\lib\csv.py in writerows(self, rowdicts)
#     156
#     157     def writerows(self, rowdicts):
# --> 158         return self.writer.writerows(map(self._dict_to_list, rowdicts))
#     159
#     160 # Guard Sniffer's type checking against builds that exclude complex()
#
# ~\Anaconda3\lib\csv.py in _dict_to_list(self, rowdict)
#     149             if wrong_fields:
#     150                 raise ValueError("dict contains fields not in fieldnames: "
# --> 151                                  + ", ".join([repr(x) for x in wrong_fields]))
#     152         return (rowdict.get(key, self.restval) for key in self.fieldnames)
#     153
#
# ...

# %%
e = pd.read_csv('Email.csv')
e
# Out:
# Empty DataFrame
# Columns: [k1, k2, k3, k4, k5, k6, k7, k8, k9, k10, k11, k12]
# Index: []

# %%
for col in DivyaMam.columns: 
    print(col)
# Out:
# Name
# email
# designaton
# dept
# institute

# %%
for col in GR.columns: 
    print(col)
# Out:
# Sl. No.
# NAME
# EMAIL ID
# Institution
# Sent Phamplet

# %%
for col in Ashini.columns: 
    print(col)
# Out:
# nairdarshan_balan@yahoo.co.in

# %%
for col in Bihar.columns: 
    print(col)
# Out:
# 1
# Dr. Amit Kumar
# Chemistry
# IIT Patna
# amitkt@iitp.ac.in
# sent

# %%
for col in Yogen.columns: 
    print(col)
# Out:
# 1
# Dr. Somendra Nath Chakraborty
# snchakraborty@cus.ac.in
# Assistant Professor, In-charge
# Chemistry
# Unnamed: 5
# Sent

# %%
for col in Priyanka.columns: 
    print(col)
# Out:
# Sl. No.
# NAME
# EMAIL ID
# DESIGNATION
# Department
# Institution
# Sent Phamplet

# %%
for col in Odisha.columns: 
    print(col)
# Out:
# 5
# Garudadhwaj Hota
# Chemistry
# NIT Rourkela
# garud@nitrkl.ac.in
# sent

# %%
for col in Raksha.columns: 
    print(col)
# Out:
# Name
# Email Id
# Address

# %%
for col in WB.columns: 
    print(col)
# Out:
# 1
# Dr. Md. Ahmaruzzaman
# Chemistry
# NIT Silchar
# md_a2002@rediffmail.com
# sent

# %%
for col in e.columns: 
    print(col)
# Out:
# k1
# k2
# k3
# k4
# k5
# k6
# k7
# k8
# k9
# k10
# k11
# k12

# %%
DivyaMam.columns =[ 'Name', 'Email', 'Appointment', 'Department', 'College'] 

DivyaMam
# Out:
#                            Name                            Email  \
# 0               Adrijit Goswami       goswami@maths.iitkgp.ac.in
# 1                 Asish Ganguly      aganguly@maths.iitkgp.ac.in
# 2           Umesh Chandra Gupta         umesh@maths.iitkgp.ac.in
# 3            Bappaditya Bhowmik    bappaditya@maths.iitkgp.ac.in
# 4               Bibhas Adhikari        bibhas@maths.iitkgp.ac.in
# 5                 Chandal Nahak        cnahak@maths.iitkgp.ac.in
# 6              Debapriya Biswas         priya@maths.iitkgp.ac.in
# 7           Debjani Chakraborty       debjani@maths.iitkgp.ac.in
# 8              Geetanjali Panda    geetanjali@maths.iitkgp.ac.in
# 9          Gnaneshwar Nelakanti       gnanesh@maths.iitkgp.ac.in
# 10              G P Raja Sekhar               rajas@iitkgp.ac.in
# 11          Hari Shankar Mahato      hsmahato@maths.iitkgp.ac.in
# 12               Jitendra Kumar        jkumar@maths.iitkgp.ac.in
# ...

# %%
Ashini.columns =['Email'] 

Ashini
# Out:
#                                Email
# 0           hod.cse@audisankara.com.
# 1           hod.cse@audisankara.com.
# 2                    jc@nerist.ac.in
# 3                 hodma@nerist.ac.in
# 4                   jc@nerist.ac.in.
# 5     principal@midnaporecollege.org
# 6         info@burdwanrajcollege.net
# 7                   rajesh@bcrec.org
# 8                b.tirimula@ieee.org
# 9              idham@math.upm.edu.my
# 10  laxmaiah.m@mlrinstitutions.ac.in
# 11          geethanjaliedu@gmail.com
# 12     RamanaReddypvr144@yahoo.co.in
# 13             sripad_k@mindtree.com
# 14             sripad_k@mindtree.com
# 15        parashar_prem@yahoo.co.in.
# 16          shivarajpundir@gmail.com
# 17         sharma-pr@uniraj.ernet.in
# 18      srivastava_a_k@lkouniv.ac.in
# 19                V_vermal@yahoo.com
# 20             torkhuranaa@yahoo.com
# 21    rajeev_chauhan1@indiatimes.com
# 22        patnammagendra@yahoo.co.in
# 23            indraj2003in@yahoo.com
# ...

# %%
Yogen.columns =[ 'SL NO.','Name' , 'Email', 'Appointment', 'Department', 'NIL', 'Pamphlet'] 

Yogen
# Out:
#     SL NO.                         Name                    Email  \
# 0        2          Dr. Sudarsan Tamang        stamang@cus.ac.in
# 1        3       Dr. Biswajit Gopal Roy          bgroy@cus.ac.in
# 2        4            Dr. Anand Pariyar       apariyar@cus.ac.in
# 3        5               Dr. Swarup Roy         sroy01@cus.ac.in
# 4        6     Dr. Mohan Pratap Pradhan      mppradhan@cus.ac.in
# 5        7           Mrs. Chunnu Khawas        ckhawas@cus.ac.in
# 6        8               Dr. Rebika Rai           rrai@cus.ac.in
# 7        9        Mr. Partha Pratim Ray          ppray@cus.ac.in
# 8       10          Mrs Lekhika Chettri       lchettri@cus.ac.in
# 9       11         Dr. Anil Kumar Misra        akmisra@cus.ac.in
# 10      12   Prof. Vinod Chandra Tiwari       vctewari@cus.ac.in
# 11      13        Dr. Rakesh Kr. Ranjan       rkranjan@cus.ac.in
# 12      14        Dr. Md. Abdullah Khan          akhan@cus.ac.in
# ...

# %%
Odisha.columns =[ 'SL NO.','Name' , 'Department', 'College', 'Email', 'Pamphlet'] 

Odisha
# Out:
#     SL NO.                           Name   Department          College  \
# 0        6              Harekrushna Sahoo    Chemistry     NIT Rourkela
# 1        7                 Priyabrat Dash    Chemistry     NIT Rourkela
# 2        8                  Aparna Mondal    Chemistry     NIT Rourkela
# 3        9       Dr. Akhilesh Kumar Singh    Chemistry  IIT Bhubaneswar
# 4       10               Dr. Ashis Biswas    Chemistry  IIT Bhubaneswar
# 5       11             Dr. Kousik Samanta    Chemistry  IIT Bhubaneswar
# 6       12               Dr. Shantanu Pal    Chemistry  IIT Bhubaneswar
# 7        1                 Biplab Ganguli      Physics     NIT Rourkela
# 8        2            Dillip Kumar Bisoyi      Physics     NIT Rourkela
# 9        3              Jyoti Prakash Kar      Physics     NIT Rourkela
# 14       16              Manish Bhattacharjee    Chemistry
# ...

# %%
Combine = pd.merge(DivyaMam, Ashini, on='Email', how='outer')

Combine
# Out:
#                        Name                            Email  \
# 0           Adrijit Goswami       goswami@maths.iitkgp.ac.in
# 1             Asish Ganguly      aganguly@maths.iitkgp.ac.in
# 2       Umesh Chandra Gupta         umesh@maths.iitkgp.ac.in
# 3        Bappaditya Bhowmik    bappaditya@maths.iitkgp.ac.in
# 4           Bibhas Adhikari        bibhas@maths.iitkgp.ac.in
# 5             Chandal Nahak        cnahak@maths.iitkgp.ac.in
# 6          Debapriya Biswas         priya@maths.iitkgp.ac.in
# 7       Debjani Chakraborty       debjani@maths.iitkgp.ac.in
# 8          Geetanjali Panda    geetanjali@maths.iitkgp.ac.in
# 9      Gnaneshwar Nelakanti       gnanesh@maths.iitkgp.ac.in
# 10          G P Raja Sekhar               rajas@iitkgp.ac.in
# 11      Hari Shankar Mahato      hsmahato@maths.iitkgp.ac.in
# 12           Jitendra Kumar        jkumar@maths.iitkgp.ac.in
# 13            Koeli Ghoshal         koeli@maths.iitkgp.ac.in
# ...

# %%
Combine = pd.merge(Combine, Ashini, on='Email', how='outer')

Combine
# Out:
#                        Name                            Email  \
# 0           Adrijit Goswami       goswami@maths.iitkgp.ac.in
# 1             Asish Ganguly      aganguly@maths.iitkgp.ac.in
# 2       Umesh Chandra Gupta         umesh@maths.iitkgp.ac.in
# 3        Bappaditya Bhowmik    bappaditya@maths.iitkgp.ac.in
# 4           Bibhas Adhikari        bibhas@maths.iitkgp.ac.in
# 5             Chandal Nahak        cnahak@maths.iitkgp.ac.in
# 6          Debapriya Biswas         priya@maths.iitkgp.ac.in
# 7       Debjani Chakraborty       debjani@maths.iitkgp.ac.in
# 8          Geetanjali Panda    geetanjali@maths.iitkgp.ac.in
# 9      Gnaneshwar Nelakanti       gnanesh@maths.iitkgp.ac.in
# 10          G P Raja Sekhar               rajas@iitkgp.ac.in
# 11      Hari Shankar Mahato      hsmahato@maths.iitkgp.ac.in
# 12           Jitendra Kumar        jkumar@maths.iitkgp.ac.in
# 13            Koeli Ghoshal         koeli@maths.iitkgp.ac.in
# ...

# %%
Combine = pd.merge(Combine, Others, on='Email', how='outer')

Combine
# Out:
#                        Name                             Email  \
# 0           Adrijit Goswami        goswami@maths.iitkgp.ac.in
# 1             Asish Ganguly       aganguly@maths.iitkgp.ac.in
# 2       Umesh Chandra Gupta          umesh@maths.iitkgp.ac.in
# 3        Bappaditya Bhowmik     bappaditya@maths.iitkgp.ac.in
# 4           Bibhas Adhikari         bibhas@maths.iitkgp.ac.in
# 5             Chandal Nahak         cnahak@maths.iitkgp.ac.in
# 6          Debapriya Biswas          priya@maths.iitkgp.ac.in
# 7       Debjani Chakraborty        debjani@maths.iitkgp.ac.in
# 8          Geetanjali Panda     geetanjali@maths.iitkgp.ac.in
# 9      Gnaneshwar Nelakanti        gnanesh@maths.iitkgp.ac.in
# 10          G P Raja Sekhar                rajas@iitkgp.ac.in
# 11      Hari Shankar Mahato       hsmahato@maths.iitkgp.ac.in
# 12           Jitendra Kumar         jkumar@maths.iitkgp.ac.in
# 13            Koeli Ghoshal          koeli@maths.iitkgp.ac.in
# ...

# %%
Combine = pd.merge(Bihar, Combine, how='outer')

Combine
# Out:
#      SL NO.                            Name Department      College  \
# 0       2.0              Dr. Debabrata Seth  Chemistry    IIT Patna
# 1       3.0  Dr. Md. Lokman Hakim Choudhury  Chemistry    IIT Patna
# 2       4.0                Dr. Neeladri Das  Chemistry    IIT Patna
# 3       5.0               Dr. Sahid Hussain  Chemistry    IIT Patna
# 4       6.0           Prof. P.K. Srivastava  Chemistry    BIT Mesra
# 5       7.0             Dr. (Mrs.) Usha Jha  Chemistry    BIT Mesra
# 6       8.0                Dr. J. P. Pandey  Chemistry    BIT Mesra
# 7       9.0               Dr. Ashoke Sharon  Chemistry    BIT Mesra
# 8      10.0                 Dr. Bimal Verma  Chemistry    BIT Mesra
# 9      11.0      Prof. (Dr.) Sitaram Sharma  Chemistry    NIT Patna
# 10     12.0               Dr Niki Sweta Jha  Chemistry    NIT Patna
# 11     13.0             Dr Pradip Kr. Sukul  Chemistry    NIT Patna
# 12     14.0              Dr. Aniruddha Paul  Chemistry    NIT Patna
# ...

# %%
Combine = pd.merge(Odisha, Combine, how='outer')
Combine
# Out:
#      SL NO.                           Name   Department          College  \
# 0       6.0              Harekrushna Sahoo    Chemistry     NIT Rourkela
# 1       7.0                 Priyabrat Dash    Chemistry     NIT Rourkela
# 2       8.0                  Aparna Mondal    Chemistry     NIT Rourkela
# 3       9.0       Dr. Akhilesh Kumar Singh    Chemistry  IIT Bhubaneswar
# 4      10.0               Dr. Ashis Biswas    Chemistry  IIT Bhubaneswar
# 5      11.0             Dr. Kousik Samanta    Chemistry  IIT Bhubaneswar
# 6      12.0               Dr. Shantanu Pal    Chemistry  IIT Bhubaneswar
# 7       1.0                 Biplab Ganguli      Physics     NIT Rourkela
# 8       2.0            Dillip Kumar Bisoyi      Physics     NIT Rourkela
# 9       3.0              Jyoti Prakash Kar      Physics     NIT Rourkela
# 10      4.0          Ananta Charan Pradhan      Physics     NIT Rourkela
# 11      5.0             Dhrubananda Behera      Physics     NIT Rourkela
# ...

# %%
Combine = pd.merge(Yogen, Combine, how='outer')

Combine
# Out:
#      SL NO.                         Name                             Email  \
# 0       2.0          Dr. Sudarsan Tamang                 stamang@cus.ac.in
# 1       3.0       Dr. Biswajit Gopal Roy                   bgroy@cus.ac.in
# 2       4.0            Dr. Anand Pariyar                apariyar@cus.ac.in
# 3       5.0               Dr. Swarup Roy                  sroy01@cus.ac.in
# 4       6.0     Dr. Mohan Pratap Pradhan               mppradhan@cus.ac.in
# 5       7.0           Mrs. Chunnu Khawas                 ckhawas@cus.ac.in
# 6       8.0               Dr. Rebika Rai                    rrai@cus.ac.in
# 7       9.0        Mr. Partha Pratim Ray                   ppray@cus.ac.in
# 8      10.0          Mrs Lekhika Chettri                lchettri@cus.ac.in
# 9      11.0         Dr. Anil Kumar Misra                 akmisra@cus.ac.in
# 10     12.0   Prof. Vinod Chandra Tiwari                vctewari@cus.ac.in
# ...

# %%
Combine = pd.merge(Combine, Raksha, how='outer')

Combine
# Out:
#       SL NO.                           Name                    Email  \
# 0        2.0            Dr. Sudarsan Tamang        stamang@cus.ac.in
# 1        3.0         Dr. Biswajit Gopal Roy          bgroy@cus.ac.in
# 2        4.0              Dr. Anand Pariyar       apariyar@cus.ac.in
# 3        5.0                 Dr. Swarup Roy         sroy01@cus.ac.in
# 4        6.0       Dr. Mohan Pratap Pradhan      mppradhan@cus.ac.in
# 5        7.0             Mrs. Chunnu Khawas        ckhawas@cus.ac.in
# 6        8.0                 Dr. Rebika Rai           rrai@cus.ac.in
# 7        9.0          Mr. Partha Pratim Ray          ppray@cus.ac.in
# 8       10.0            Mrs Lekhika Chettri       lchettri@cus.ac.in
# 9       11.0           Dr. Anil Kumar Misra        akmisra@cus.ac.in
# 10      12.0     Prof. Vinod Chandra Tiwari       vctewari@cus.ac.in
# 11      13.0          Dr. Rakesh Kr. Ranjan       rkranjan@cus.ac.in
# 12      14.0          Dr. Md. Abdullah Khan          akhan@cus.ac.in
# ...

# %%
Combine = pd.merge(Combine, Sheet12, how='outer')

Combine
# Out:
#       SL NO.                         Name                          Email  \
# 0        2.0          Dr. Sudarsan Tamang              stamang@cus.ac.in
# 1        3.0       Dr. Biswajit Gopal Roy                bgroy@cus.ac.in
# 2        4.0            Dr. Anand Pariyar             apariyar@cus.ac.in
# 3        5.0               Dr. Swarup Roy               sroy01@cus.ac.in
# 4        6.0     Dr. Mohan Pratap Pradhan            mppradhan@cus.ac.in
# 5        7.0           Mrs. Chunnu Khawas              ckhawas@cus.ac.in
# 6        8.0               Dr. Rebika Rai                 rrai@cus.ac.in
# 7        9.0        Mr. Partha Pratim Ray                ppray@cus.ac.in
# 8       10.0          Mrs Lekhika Chettri             lchettri@cus.ac.in
# 9       11.0         Dr. Anil Kumar Misra              akmisra@cus.ac.in
# 10      12.0   Prof. Vinod Chandra Tiwari             vctewari@cus.ac.in
# 11      13.0        Dr. Rakesh Kr. Ranjan             rkranjan@cus.ac.in
# ...

# %%
Combine = pd.merge(Combine, dam, how='outer')

Combine
# Out:
#       SL NO.                         Name  \
# 0        2.0          Dr. Sudarsan Tamang
# 1        3.0       Dr. Biswajit Gopal Roy
# 2        4.0            Dr. Anand Pariyar
# 3        5.0               Dr. Swarup Roy
# 4        6.0     Dr. Mohan Pratap Pradhan
# 5        7.0           Mrs. Chunnu Khawas
# 6        8.0               Dr. Rebika Rai
# 7        9.0        Mr. Partha Pratim Ray
# 8       10.0          Mrs Lekhika Chettri
# 9       11.0         Dr. Anil Kumar Misra
# 10      12.0   Prof. Vinod Chandra Tiwari
# 11      13.0        Dr. Rakesh Kr. Ranjan
# 12      14.0        Dr. Md. Abdullah Khan
# 13      15.0         Dr. Nishchal Wanjari
# 14      16.0  Dr. Badikar Ananda Ganapati
# 15      17.0       Shri Om Prakash Kaptan
# 16      18.0     Dr. Thoudam Roshan Singh
# 17      19.0           Ms. Rinkila Bhutia
# 18      20.0                Dr. Bipul Pal
# 19      21.0            Dr. Namita Behera
# 20      22.0            Prof. P.K. Sharma
# ...

# %%
cols = ['SL NO.', 'Name', 'Email', 'Appointment', 'Department', 'NIL', 'Pamphlet', 'College', 'Email Id', 'Address']

# %%
# Out:
# ['SL NO.',
#  'Name',
#  'Email',
#  'Appointment',
#  'Department',
#  'NIL',
#  'Pamphlet',
#  'College',
#  'Email Id',
#  'Address']

# %%
Combine.duplicated().sum()
# Out:
# 36

# %%
Combine.loc[Combine.duplicated(keep='first'), :]
# Out:
#      SL NO. Name                     Email Appointment Department  NIL  \
# 496     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 497     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 498     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 499     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 500     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 501     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 502     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 503     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 504     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 505     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 506     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# 507     NaN  NaN  hod.cse@audisankara.com.         NaN        NaN  NaN
# ...

# %%
Combine.drop_duplicates(keep='first')
# Out:
#       SL NO.                         Name  \
# 0        2.0          Dr. Sudarsan Tamang
# 1        3.0       Dr. Biswajit Gopal Roy
# 2        4.0            Dr. Anand Pariyar
# 3        5.0               Dr. Swarup Roy
# 4        6.0     Dr. Mohan Pratap Pradhan
# 5        7.0           Mrs. Chunnu Khawas
# 6        8.0               Dr. Rebika Rai
# 7        9.0        Mr. Partha Pratim Ray
# 8       10.0          Mrs Lekhika Chettri
# 9       11.0         Dr. Anil Kumar Misra
# 10      12.0   Prof. Vinod Chandra Tiwari
# 11      13.0        Dr. Rakesh Kr. Ranjan
# 12      14.0        Dr. Md. Abdullah Khan
# 13      15.0         Dr. Nishchal Wanjari
# 14      16.0  Dr. Badikar Ananda Ganapati
# 15      17.0       Shri Om Prakash Kaptan
# 16      18.0     Dr. Thoudam Roshan Singh
# 17      19.0           Ms. Rinkila Bhutia
# 18      20.0                Dr. Bipul Pal
# 19      21.0            Dr. Namita Behera
# 20      22.0            Prof. P.K. Sharma
# ...
